# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\koush\\OneDrive\\Documents\\doctor visit.csv")
data
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 3              4       1    male  0.19    0.15        1        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  visits  gender   age  income  illness  reduced  health private  \
# 0           1       1  female  0.19    0.55        1        4       1     yes
# 1           2       1  female  0.19    0.45        1        2       1     yes
# 2           3       1    male  0.19    0.90        3        0       0      no
# 3           4       1    male  0.19    0.15        1        0       0      no
# 4           5       1    male  0.19    0.45        2        5       1      no
#
#   freepoor freerepat nchronic lchronic
# 0       no        no       no       no
# 1       no        no       no       no
# 2       no        no       no       no
# 3       no        no       no       no
# 4       no        no      yes       no

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# visits        0
# gender        0
# age           0
# income        0
# illness       0
# reduced       0
# health        0
# private       0
# freepoor      0
# freerepat     0
# nchronic      0
# lchronic      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.rename(columns={"Unnamed: 0":"patient_id"},inplace=True)

# %%
data.income = (data.income*100000).astype(int)

# %%
data.age = [int(str(val).split(".")[1]) for val in data.age]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   patient_id  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   int64
#  4   income      5190 non-null   int64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: int64(7), object(6)
# memory usage: 527.2+ KB

# %%
data.describe()
# Out:
#         patient_id       visits          age         income      illness  \
# count  5190.000000  5190.000000  5190.000000    5190.000000  5190.000000
# mean   2595.500000     0.301734    40.638536   58315.992293     1.431985
# std    1498.368279     0.798134    20.478182   36890.669837     1.384152
# min       1.000000     0.000000    19.000000       0.000000     0.000000
# 25%    1298.250000     0.000000    22.000000   25000.000000     0.000000
# 50%    2595.500000     0.000000    32.000000   55000.000000     1.000000
# 75%    3892.750000     0.000000    62.000000   90000.000000     2.000000
# max    5190.000000     9.000000    72.000000  150000.000000     5.000000
#
#            reduced       health
# count  5190.000000  5190.000000
# mean      0.861850     1.217534
# std       2.887628     2.124266
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     2.000000
# max      14.000000    12.000000

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x=data.gender)
plt.ylabel('No. of patients')
plt.title('Total count of patients by gender')
plt.show()

# %%
plt.figure(figsize=(11, 4))
sns.countplot(hue=data.gender, x=data.age)
plt.ylabel('No. of patients')
plt.title('Patients by Age (separated by gender)')
plt.show()

# %%
plt.figure(figsize=(12, 4))
sns.barplot(x='age', y='visits', data=data)
plt.title("Average Doctor Visits by Age")
plt.xlabel("Age")
plt.ylabel("Average Visits")
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x=data.private)
plt.ylabel('No. of patients')
plt.title('Patients with Private Health Insurance')
plt.show()
